# %% [markdown]
# # M1A5 - Operações Básicas em Imagens

# %% [markdown]
# Na aula de hoje iremos continuar explorando algumas operações da [OpenCV](https://opencv.org/)
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Transformações de imagens (recorte, translação e rotação)
# - Funções utilitárias de desenhos
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# !pip install opencv-python
# !pip install matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\mcami\onedrive\computer vision\modulo_1\vc_m1a5 - operações básicas em imagens\.venv\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\mcami\onedrive\computer vision\modulo_1\vc_m1a5 - operações básicas em imagens\.venv\lib\site-packages (from opencv-python) (2.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\mcami\onedrive\computer vision\modulo_1\vc_m1a5 - operações básicas em imagens\.venv\lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\mcami\onedrive\computer vision\modulo_1\vc_m1a5 - operações básicas em imagens\.venv\lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mcami\onedrive\computer vision\modulo_1\vc_m1a5 - operações básicas em imagens\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mcami\onedrive\computer vision\modulo_1\vc_m1a5 - operações básicas em imagens\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Using cached pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importar as bibliotecas e Ler Imagens do Disco

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# TODO Atualize o path da imagem.
image = cv2.imread("bahia.jpeg")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Transformações de Imagens

# %% [markdown]
# Nessa prática iremos ver como realizar transformações simples mas extremamente úteis em imagens utilizando OpenCV.

# %%
crop = image[0:500, 0:500]
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))
axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[1].imshow(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))

# %%
# Dimensões da imagem original.
height, width = image.shape[:2]

# Matriz de translação.
translation_x, translation_y = 800, 400
translation_matrix = np.float32([
    [1, 0, translation_x],
    [0, 1, translation_y]
])

# Aplicando a matriz de transformação na imagem.
translated = cv2.warpAffine(image, translation_matrix, (width, height))

# Visualizando os resultados.
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))
axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[1].imshow(cv2.cvtColor(translated, cv2.COLOR_BGR2RGB))

# %%
# Dimensões da imagem original.
height, width = image.shape[:2]

# Definindo o centro da rotação.
center = (width // 2, height // 2)
 
# Define o ângulo de rotação.
angle = 45  # Rotacionar por 45 graus.
 
# Define uma operação de escala da imagem.
scale = 1.0  # Sem escala.
 
# Deriva a matriz de rotação
rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)
 
# Aplica a matriz de transformação na imagem.
rotated = cv2.warpAffine(image, rotation_matrix, (width, height))

# Visualizando os resultados.
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))
axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[1].imshow(cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Funções utilitárias de Desenhos

# %% [markdown]
# Agora iremos ver como desenhar padrões nas imagens usando OpenCV.

# %%
image_draw = cv2.rectangle(image, (100,200), (500,500), (0,0,255), 5)
plt.imshow(cv2.cvtColor(image_draw, cv2.COLOR_BGR2RGB))

# %% [markdown]
# E esse é o final dessa prática.

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas vamos continuar explorando OpenCV.
#
# Uma lista não exaustiva de referências segue:
#
# - https://opencv.org/blog/image-rotation-and-translation-using-opencv/
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opicional)

# %% [markdown]
# - [ ] Leia a outra imagem do arquivo `rio.jpeg` e rode todos os comandos.
# - [ ] Pense em outras transformações que podem fazer sentido e veja de OpenCV já as implementa.
# - [ ] Tente desenhar outros formatos, e textos na imagem.
